# %% [markdown]
# <a href="https://colab.research.google.com/github/meganwiehe/Final-Repo-Group-5/blob/main/Group5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import requests
import geopandas as gpd

# %% [markdown]
# ### Health Department Food Inspection Tracker
#
# 1. Go to the Chicago Data Portal: https://data.cityofchicago.org/
# 2. Find each dataset. Building violations, ward, and police.
# 3. Add a data notes section to your github readme. This should include information about the source of your data, where it came from, how often it is updated, and the period of data it contains (e.g. 2010-present or 2012 to 2019)
# 4. Lastly, test that this import works. This may take a while as the dataset is large.

# %%
hd = pd.read_csv("https://data.cityofchicago.org/resource/4ijn-s7e5.csv?$limit=500000")
# you can use any of these
ward = gpd.read_file('https://data.cityofchicago.org/api/geospatial/sp34-6z76?method=export&format=GeoJSON')
police = gpd.read_file('https://data.cityofchicago.org/api/geospatial/fthy-xz3r?method=export&format=GeoJSON')

# %%
hd.head()
# Out:
#    inspection_id                               dba_name  \
# 0        2593062                  TEENY TINY UNIVERSITY
# 1        2593052           NYC HALAL EATS ILLINOIS  LLC
# 2        2593066               91st South Chicago Apts.
# 3        2593064  CHRISTIAN L-E-G EARLY LEARNING CENTER
# 4        2593058                        MAKKI MART CORP
#
#                                 aka_name   license_  \
# 0                  TEENY TINY UNIVERSITY  2517601.0
# 1           NYC HALAL EATS ILLINOIS  LLC  2961706.0
# 2                        MAHALIA JACKSON  2046644.0
# 3  CHRISTIAN L-E-G EARLY LEARNING CENTER  2363607.0
# 4                             MAKKI MART  2550262.0
#
#                      facility_type             risk  \
# 0  Daycare Above and Under 2 Years    Risk 1 (High)
# 1                       Restaurant  Risk 2 (Medium)
# 2                     Golden Diner    Risk 1 (High)
# 3     Children's Services Facility    Risk 1 (High)
# 4                    Grocery Store  Risk 2 (Medium)
#
#                      address     city state      zip          inspection_date  \
# 0  6111 S COTTAGE GROVE AVE   CHICAGO    IL  60637.0  2024-04-19T00:00:00.000
# 1          2657 W DEVON AVE   CHICAGO    IL  60659.0  2024-04-19T00:00:00.000
# 2  9177 S SOUTH CHICAGO AVE   CHICAGO    IL  60617.0  2024-04-19T00:00:00.000
# 3         446-448 E 43RD ST   CHICAGO    IL  60653.0  2024-04-19T00:00:00.000
# 4          2440 W DEVON AVE   CHICAGO    IL  60659.0  2024-04-19T00:00:00.000
#
#            inspection_type results  \
# 0                  Canvass    Pass
# 1    License Re-Inspection    Fail
# 2                  Canvass    Fail
# 3                  Canvass    Pass
# 4  Complaint Re-Inspection    Fail
#
#                                           violations   latitude  longitude  \
# 0  55. PHYSICAL FACILITIES INSTALLED, MAINTAINED ...  41.783684 -87.605855
# 1  3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL E...  41.997495 -87.697056
# 2  1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOW...  41.728634 -87.553603
# 3  51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICE...  41.816782 -87.614640
# 4  38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - ...  41.997814 -87.691506
#
#                                   location
# 0   (41.78368442665007, -87.6058547469109)
# 1  (41.99749525704475, -87.69705608404989)
# 2  (41.72863395838726, -87.55360264844659)
# 3  (41.81678222761027, -87.61463973808141)
# 4  (41.99781439642854, -87.69150610963688)

# %%
police.head()
# Out:
#   dist_label dist_num                                           geometry
# 0       17TH       17  MULTIPOLYGON (((-87.71067 41.99737, -87.71067 ...
# 1       20TH       20  MULTIPOLYGON (((-87.66029 41.99092, -87.66029 ...
# 2       31ST       31  MULTIPOLYGON (((-87.82818 41.98384, -87.82816 ...
# 3       31ST       31  MULTIPOLYGON (((-87.83365 41.97535, -87.83366 ...
# 4       19TH       19  MULTIPOLYGON (((-87.64492 41.96973, -87.64431 ...

# %%
ward.head()
# Out:
#       shape_area     shape_leng ward  \
# 0  116096507.849  93073.3408379   12
# 1  103143638.546  97901.3238332   16
# 2   65588297.917  82183.6948197   15
# 3   137290356.97  90105.1956185   20
# 4  49733459.1385  38122.6928259   49
#
#                                             geometry
# 0  MULTIPOLYGON (((-87.69623 41.85755, -87.69625 ...
# 1  MULTIPOLYGON (((-87.66289 41.79884, -87.66289 ...
# 2  MULTIPOLYGON (((-87.69818 41.81729, -87.69817 ...
# 3  MULTIPOLYGON (((-87.65524 41.80883, -87.65524 ...
# 4  MULTIPOLYGON (((-87.66420 42.02126, -87.66419 ...

# %%
hd.tail()
# Out:
#         inspection_id                      dba_name  \
# 270951          67732                     WOLCOTT'S
# 270952          70269                   mr.daniel's
# 270953          67738        MICHAEL'S ON MAIN CAFE
# 270954         104236                    TEMPO CAFE
# 270955          67757  DUNKIN DONUTS/BASKIN-ROBBINS
#
#                             aka_name   license_ facility_type  \
# 270951                       TROQUET  1992039.0    Restaurant
# 270952                   mr.daniel's  1899292.0    Restaurant
# 270953        MICHAEL'S ON MAIN CAFE  2008948.0    Restaurant
# 270954                    TEMPO CAFE    80916.0    Restaurant
# 270955  DUNKIN DONUTS/BASKIN-ROBBINS  1380279.0    Restaurant
#
#                    risk                address     city state      zip  \
# 270951    Risk 1 (High)   1834 W MONTROSE AVE   CHICAGO    IL  60613.0
# 270952    Risk 1 (High)    5645 W BELMONT AVE   CHICAGO    IL  60634.0
# 270953    Risk 1 (High)  8750 W BRYN WAWR AVE   CHICAGO    IL  60631.0
# 270954    Risk 1 (High)       6 E CHESTNUT ST   CHICAGO    IL  60611.0
# 270955  Risk 2 (Medium)     100 W RANDOLPH ST   CHICAGO    IL  60601.0
#
#                 inspection_date        inspection_type results  \
# 270951  2010-01-04T00:00:00.000  License Re-Inspection    Pass
# 270952  2010-01-04T00:00:00.000  License Re-Inspection    Pass
# 270953  2010-01-04T00:00:00.000                License    Fail
# 270954  2010-01-04T00:00:00.000                Canvass    Fail
# 270955  2010-01-04T00:00:00.000            Tag Removal    Pass
#
#                                                violations   latitude  \
# 270951                                                NaN  41.961606
# 270952                                                NaN  41.938443
# 270953  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...        NaN
# 270954  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.898431
# 270955                                                NaN  41.884586
#
#         longitude                                  location
# 270951 -87.675967  (41.961605669949854, -87.67596676683779)
# 270952 -87.768318   (41.93844282365204, -87.76831838068422)
# 270953        NaN                                       NaN
# 270954 -87.628009    (41.89843137207629, -87.6280091630558)
# 270955 -87.631010   (41.88458626715456, -87.63101044588599)

# %%
ward.tail()
# Out:
#        shape_area     shape_leng ward  \
# 45  163221187.276  130222.911895   27
# 46   548958842.58  144026.595563   10
# 47  142093459.943  82824.4632842   11
# 48  70391187.5645  69089.8822547   26
# 49  125334245.511  76714.8413866   45
#
#                                              geometry
# 45  MULTIPOLYGON (((-87.63666 41.91120, -87.63666 ...
# 46  MULTIPOLYGON (((-87.57838 41.64469, -87.57842 ...
# 47  MULTIPOLYGON (((-87.64672 41.87432, -87.64653 ...
# 48  MULTIPOLYGON (((-87.70703 41.91923, -87.70700 ...
# 49  MULTIPOLYGON (((-87.77835 41.99020, -87.77808 ...

# %%
police.tail(20)
# Out:
#    dist_label dist_num                                           geometry
# 5        25TH       25  MULTIPOLYGON (((-87.71740 41.93922, -87.71739 ...
# 6        14TH       14  MULTIPOLYGON (((-87.69257 41.93943, -87.69253 ...
# 7        31ST       31  MULTIPOLYGON (((-87.69123 41.69899, -87.69123 ...
# 8        22ND       22  MULTIPOLYGON (((-87.63632 41.73618, -87.63592 ...
# 9         5TH        5  MULTIPOLYGON (((-87.58776 41.72231, -87.58762 ...
# 10       24TH       24  MULTIPOLYGON (((-87.67424 42.02300, -87.66541 ...
# 11       16TH       16  MULTIPOLYGON (((-87.80655 42.01896, -87.80655 ...
# 12        8TH        8  MULTIPOLYGON (((-87.71442 41.82861, -87.71433 ...
# 13       18TH       18  MULTIPOLYGON (((-87.63068 41.92623, -87.62960 ...
# 14       12TH       12  MULTIPOLYGON (((-87.65742 41.90351, -87.65739 ...
# 15       11TH       11  MULTIPOLYGON (((-87.70679 41.90283, -87.70679 ...
# 16        7TH        7  MULTIPOLYGON (((-87.63076 41.79420, -87.63076 ...
# 17        3RD        3  MULTIPOLYGON (((-87.58001 41.79348, -87.57949 ...
# 18        4TH        4  MULTIPOLYGON (((-87.55547 41.76135, -87.55475 ...
# 19        6TH        6  MULTIPOLYGON (((-87.59800 41.75865, -87.59778 ...
# 20       10TH       10  MULTIPOLYGON (((-87.68604 41.86661, -87.68603 ...
# 21        1ST        1  MULTIPOLYGON (((-87.62437 41.88886, -87.62419 ...
# 22        9TH        9  MULTIPOLYGON (((-87.63193 41.86015, -87.63117 ...
# 23        2ND        2  MULTIPOLYGON (((-87.60769 41.83858, -87.60618 ...
# 24       15TH       15  MULTIPOLYGON (((-87.74598 41.90235, -87.74598 ...

# %%
hd.columns
# Out:
# Index(['inspection_id', 'dba_name', 'aka_name', 'license_', 'facility_type',
#        'risk', 'address', 'city', 'state', 'zip', 'inspection_date',
#        'inspection_type', 'results', 'violations', 'latitude', 'longitude',
#        'location'],
#       dtype='object')

# %%
ward.columns
# Out:
# Index(['shape_area', 'shape_leng', 'ward', 'geometry'], dtype='object')

# %%
police.columns
# Out:
# Index(['dist_label', 'dist_num', 'geometry'], dtype='object')

# %%
hd.shape
# Out:
# (270956, 17)

# %%
ward.shape
# Out:
# (50, 4)

# %%
police.shape
# Out:
# (25, 3)

# %%
hd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270956 entries, 0 to 270955
# Data columns (total 17 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   inspection_id    270956 non-null  int64
#  1   dba_name         270956 non-null  object
#  2   aka_name         268484 non-null  object
#  3   license_         270938 non-null  float64
#  4   facility_type    265814 non-null  object
#  5   risk             270873 non-null  object
#  6   address          270956 non-null  object
#  7   city             270795 non-null  object
#  8   state            270897 non-null  object
#  9   zip              270905 non-null  float64
#  10  inspection_date  270956 non-null  object
#  11  inspection_type  270955 non-null  object
#  12  results          270956 non-null  object
#  13  violations       196645 non-null  object
#  14  latitude         270018 non-null  float64
#  15  longitude        270018 non-null  float64
#  16  location         270018 non-null  object
# dtypes: float64(4), int64(1), object(12)
# memory usage: 35.1+ MB

# %%
police.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   dist_label  25 non-null     object
#  1   dist_num    25 non-null     object
#  2   geometry    25 non-null     geometry
# dtypes: geometry(1), object(2)
# memory usage: 728.0+ bytes

# %%
ward.info(5)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   shape_area  50 non-null     object
#  1   shape_leng  50 non-null     object
#  2   ward        50 non-null     object
#  3   geometry    50 non-null     geometry
# dtypes: geometry(1), object(3)
# memory usage: 1.7+ KB

# %% [markdown]
# Must convert data types at least once
#  pd.to_numeric()
# pd.to_datetime()

# %%
hd['inspection_id'] = pd.to_datetime(hd['inspection_date'])

# %%
pd.date_range('2019-4-21', '2024-04-21', freq = 'D')
# Out:
# DatetimeIndex(['2019-04-21', '2019-04-22', '2019-04-23', '2019-04-24',
#                '2019-04-25', '2019-04-26', '2019-04-27', '2019-04-28',
#                '2019-04-29', '2019-04-30',
#                ...
#                '2024-04-12', '2024-04-13', '2024-04-14', '2024-04-15',
#                '2024-04-16', '2024-04-17', '2024-04-18', '2024-04-19',
#                '2024-04-20', '2024-04-21'],
#               dtype='datetime64[ns]', length=1828, freq='D')

# %%
pd.date_range('2019-4-21', '2024-04-21', freq = 'M')
# Out:
# DatetimeIndex(['2019-04-30', '2019-05-31', '2019-06-30', '2019-07-31',
#                '2019-08-31', '2019-09-30', '2019-10-31', '2019-11-30',
#                '2019-12-31', '2020-01-31', '2020-02-29', '2020-03-31',
#                '2020-04-30', '2020-05-31', '2020-06-30', '2020-07-31',
#                '2020-08-31', '2020-09-30', '2020-10-31', '2020-11-30',
#                '2020-12-31', '2021-01-31', '2021-02-28', '2021-03-31',
#                '2021-04-30', '2021-05-31', '2021-06-30', '2021-07-31',
#                '2021-08-31', '2021-09-30', '2021-10-31', '2021-11-30',
#                '2021-12-31', '2022-01-31', '2022-02-28', '2022-03-31',
#                '2022-04-30', '2022-05-31', '2022-06-30', '2022-07-31',
#                '2022-08-31', '2022-09-30', '2022-10-31', '2022-11-30',
#                '2022-12-31', '2023-01-31', '2023-02-28', '2023-03-31',
#                '2023-04-30', '2023-05-31', '2023-06-30', '2023-07-31',
#                '2023-08-31', '2023-09-30', '2023-10-31', '2023-11-30',
#                '2023-12-31', '2024-01-31', '2024-02-29', '2024-03-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
pd.date_range('2019-4-21', '2024-04-21', freq = 'Y')
# Out:
# DatetimeIndex(['2019-12-31', '2020-12-31', '2021-12-31', '2022-12-31',
#                '2023-12-31'],
#               dtype='datetime64[ns]', freq='A-DEC')

# %%
hd_melt = pd.melt( hd , id_vars=['inspection_date'], value_vars=['results' , 'inspection_date'] )

# %%
hd_melt.head(10)

# %%
hd_melt.info()

# %%
hd_melt.sort_values(['inspection_date','value' ]).head(10)
