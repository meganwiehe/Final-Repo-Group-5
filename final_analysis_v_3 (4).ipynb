# %%
import pandas as pd
import numpy as np
import requests
import geopandas as gpd

# %%
hd = pd.read_csv("https://data.cityofchicago.org/resource/4ijn-s7e5.csv?$limit=500000")
# you can use any of these
ward = gpd.read_file('https://data.cityofchicago.org/api/geospatial/sp34-6z76?method=export&format=GeoJSON')
police = gpd.read_file('https://data.cityofchicago.org/api/geospatial/fthy-xz3r?method=export&format=GeoJSON')

# %% [markdown]
# **Analyzing data**

# %%
hd.head()
# Out:
#    inspection_id                      dba_name                      aka_name  \
# 0        2593156                     MARIANO'S                     MARIANO'S
# 1        2593140              ALL TOGETHER NOW               ALLTOGETHER NOW
# 2        2593144          MERCADITO LA MONARCA          MERCADITO LA MONARCA
# 3        2593149  Supermercado  Castillos, Inc  Supermercado  Castillos, Inc
# 4        2593119             SKY CHOP SUEY INC             SKY CHOP SUEY INC
#
#     license_  facility_type             risk              address     city  \
# 0  2271471.0  Grocery Store    Risk 1 (High)     1615 S CLARK ST   CHICAGO
# 1  2589262.0     Restaurant    Risk 1 (High)  2119 W CHICAGO AVE   CHICAGO
# 2  2956597.0  Grocery Store    Risk 1 (High)      2732 W 59TH ST   CHICAGO
# 3  2004134.0  Grocery Store  Risk 2 (Medium)      2732 W 59TH ST   CHICAGO
# 4    25159.0     Restaurant    Risk 1 (High)   8616 S KEDZIE AVE   CHICAGO
#
#   state      zip          inspection_date          inspection_type  \
# 0    IL  60616.0  2024-04-22T00:00:00.000                Complaint
# 1    IL  60622.0  2024-04-22T00:00:00.000                  Canvass
# 2    IL  60629.0  2024-04-22T00:00:00.000    License Re-Inspection
# 3    IL  60629.0  2024-04-22T00:00:00.000                  Canvass
# 4    IL  60652.0  2024-04-22T00:00:00.000  Complaint Re-Inspection
#
#               results                                         violations  \
# 0                Pass  36. THERMOMETERS PROVIDED & ACCURATE - Comment...
# 1  Pass w/ Conditions  2. CITY OF CHICAGO FOOD SERVICE SANITATION CER...
# 2                Pass  39. CONTAMINATION PREVENTED DURING FOOD PREPAR...
# 3     Out of Business                                                NaN
# 4                Fail  38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - ...
#
#     latitude  longitude                                 location
# 0  41.859630 -87.630125  (41.85962967731282, -87.63012489927696)
# 1  41.895745 -87.680303   (41.89574547491271, -87.6803034146672)
# 2  41.786536 -87.692440  (41.78653601978693, -87.69244039932887)
# 3  41.786536 -87.692440  (41.78653601978693, -87.69244039932887)
# 4  41.736414 -87.702192   (41.7364142354004, -87.70219239358123)

# %%
hd.tail()
# Out:
#         inspection_id                      dba_name  \
# 271018         104236                    TEMPO CAFE
# 271019          67757  DUNKIN DONUTS/BASKIN-ROBBINS
# 271020          67732                     WOLCOTT'S
# 271021          67738        MICHAEL'S ON MAIN CAFE
# 271022          52234                      Cafe 608
#
#                             aka_name   license_ facility_type  \
# 271018                    TEMPO CAFE    80916.0    Restaurant
# 271019  DUNKIN DONUTS/BASKIN-ROBBINS  1380279.0    Restaurant
# 271020                       TROQUET  1992039.0    Restaurant
# 271021        MICHAEL'S ON MAIN CAFE  2008948.0    Restaurant
# 271022                      Cafe 608  2013328.0    Restaurant
#
#                    risk                address     city state      zip  \
# 271018    Risk 1 (High)       6 E CHESTNUT ST   CHICAGO    IL  60611.0
# 271019  Risk 2 (Medium)     100 W RANDOLPH ST   CHICAGO    IL  60601.0
# 271020    Risk 1 (High)   1834 W MONTROSE AVE   CHICAGO    IL  60613.0
# 271021    Risk 1 (High)  8750 W BRYN WAWR AVE   CHICAGO    IL  60631.0
# 271022    Risk 1 (High)       608 W BARRY AVE   CHICAGO    IL  60657.0
#
#                 inspection_date        inspection_type results  \
# 271018  2010-01-04T00:00:00.000                Canvass    Fail
# 271019  2010-01-04T00:00:00.000            Tag Removal    Pass
# 271020  2010-01-04T00:00:00.000  License Re-Inspection    Pass
# 271021  2010-01-04T00:00:00.000                License    Fail
# 271022  2010-01-04T00:00:00.000  License Re-Inspection    Pass
#
#                                                violations   latitude  \
# 271018  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.898431
# 271019                                                NaN  41.884586
# 271020                                                NaN  41.961606
# 271021  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...        NaN
# 271022                                                NaN  41.938007
#
#         longitude                                  location
# 271018 -87.628009    (41.89843137207629, -87.6280091630558)
# 271019 -87.631010   (41.88458626715456, -87.63101044588599)
# 271020 -87.675967  (41.961605669949854, -87.67596676683779)
# 271021        NaN                                       NaN
# 271022 -87.644755   (41.938006880423615, -87.6447545707008)

# %%
hd.columns
# Out:
# Index(['inspection_id', 'dba_name', 'aka_name', 'license_', 'facility_type',
#        'risk', 'address', 'city', 'state', 'zip', 'inspection_date',
#        'inspection_type', 'results', 'violations', 'latitude', 'longitude',
#        'location'],
#       dtype='object')

# %%
hd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271023 entries, 0 to 271022
# Data columns (total 17 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   inspection_id    271023 non-null  int64
#  1   dba_name         271023 non-null  object
#  2   aka_name         268551 non-null  object
#  3   license_         271005 non-null  float64
#  4   facility_type    265882 non-null  object
#  5   risk             270940 non-null  object
#  6   address          271023 non-null  object
#  7   city             270862 non-null  object
#  8   state            270964 non-null  object
#  9   zip              270972 non-null  float64
#  10  inspection_date  271023 non-null  object
#  11  inspection_type  271022 non-null  object
#  12  results          271023 non-null  object
#  13  violations       196697 non-null  object
#  14  latitude         270085 non-null  float64
#  15  longitude        270085 non-null  float64
#  16  location         270085 non-null  object
# dtypes: float64(4), int64(1), object(12)
# memory usage: 35.2+ MB

# %%
hd.shape
# Out:
# (271023, 17)

# %% [markdown]
# **Analyzing how many restaurants are inspected every month/year**

# %% [markdown]
# Creating new columns

# %%
hd['inspection_date'] = pd.to_datetime(hd['inspection_date'])

# %%
hd['inspection_date'].value_counts()
# Out:
# inspection_date
# 2013-11-14    185
# 2016-09-13    149
# 2016-11-29    145
# 2014-12-16    143
# 2014-12-03    142
#              ...
# 2010-08-07      1
# 2017-01-09      1
# 2010-12-18      1
# 2011-02-11      1
# 2017-02-06      1
# Name: count, Length: 3611, dtype: int64

# %%
hd['inc_year'] = hd['inspection_date'].dt.year
hd['inc_month'] = hd['inspection_date'].dt.month
hd['inc_week'] = hd['inspection_date'].dt.weekday
hd['inc_day'] = hd['inspection_date'].dt.day

# %%
hd['year_month'] = hd['inc_year'].astype(str) + "-" + hd['inc_month'].astype(str) + "-01"

# %%
hd['count'] = 1

# %% [markdown]
# running groupby

# %%
hd.groupby('year_month')['count'].sum()
# Out:
# year_month
# 2010-1-01     1279
# 2010-10-01    1814
# 2010-11-01    1294
# 2010-12-01    1278
# 2010-2-01     1399
#               ...
# 2023-9-01     1535
# 2024-1-01     1367
# 2024-2-01     1345
# 2024-3-01     1457
# 2024-4-01      937
# Name: count, Length: 172, dtype: int64

# %%
hd.groupby('year_month')['count'].sum().mean()
# Out:
# 1575.7151162790697

# %%
year_month = hd.groupby('year_month')['count'].sum()

# %%
year_month.to_csv('year_month')

# %% [markdown]
# Inspections done per month - https://datawrapper.dwcdn.net/8o95a/1/
#
# Inspections done per year - https://datawrapper.dwcdn.net/1UWqG/4/

# %% [markdown]
# **Analyzing how many restaurants are inspected by geographical area**

# %% [markdown]
# **Analyzing how many restaurants receive either a downgraded or upgraded inspection and Failing or Passing grade**

# %%
hd.columns
# Out:
# Index(['inspection_id', 'dba_name', 'aka_name', 'license_', 'facility_type',
#        'risk', 'address', 'city', 'state', 'zip', 'inspection_date',
#        'inspection_type', 'results', 'violations', 'latitude', 'longitude',
#        'location', 'inc_year', 'inc_month', 'inc_week', 'inc_day',
#        'year_month', 'count'],
#       dtype='object')

# %%
hd.shape
# Out:
# (271023, 23)

# %%
hd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271023 entries, 0 to 271022
# Data columns (total 23 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   inspection_id    271023 non-null  int64
#  1   dba_name         271023 non-null  object
#  2   aka_name         268551 non-null  object
#  3   license_         271005 non-null  float64
#  4   facility_type    265882 non-null  object
#  5   risk             270940 non-null  object
#  6   address          271023 non-null  object
#  7   city             270862 non-null  object
#  8   state            270964 non-null  object
#  9   zip              270972 non-null  float64
#  10  inspection_date  271023 non-null  datetime64[ns]
#  11  inspection_type  271022 non-null  object
#  12  results          271023 non-null  object
#  13  violations       196697 non-null  object
#  14  latitude         270085 non-null  float64
#  15  longitude        270085 non-null  float64
#  16  location         270085 non-null  object
#  17  inc_year         271023 non-null  int32
#  18  inc_month        271023 non-null  int32
#  19  inc_week         271023 non-null  int32
#  20  inc_day          271023 non-null  int32
#  21  year_month       271023 non-null  object
#  22  count            271023 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int32(4), int64(2), object(12)
# memory usage: 43.4+ MB

# %%
hd.head()
# Out:
#    inspection_id                      dba_name                      aka_name  \
# 0        2593156                     MARIANO'S                     MARIANO'S
# 1        2593140              ALL TOGETHER NOW               ALLTOGETHER NOW
# 2        2593144          MERCADITO LA MONARCA          MERCADITO LA MONARCA
# 3        2593149  Supermercado  Castillos, Inc  Supermercado  Castillos, Inc
# 4        2593119             SKY CHOP SUEY INC             SKY CHOP SUEY INC
#
#     license_  facility_type             risk              address     city  \
# 0  2271471.0  Grocery Store    Risk 1 (High)     1615 S CLARK ST   CHICAGO
# 1  2589262.0     Restaurant    Risk 1 (High)  2119 W CHICAGO AVE   CHICAGO
# 2  2956597.0  Grocery Store    Risk 1 (High)      2732 W 59TH ST   CHICAGO
# 3  2004134.0  Grocery Store  Risk 2 (Medium)      2732 W 59TH ST   CHICAGO
# 4    25159.0     Restaurant    Risk 1 (High)   8616 S KEDZIE AVE   CHICAGO
#
#   state      zip  ...                                         violations  \
# 0    IL  60616.0  ...  36. THERMOMETERS PROVIDED & ACCURATE - Comment...
# 1    IL  60622.0  ...  2. CITY OF CHICAGO FOOD SERVICE SANITATION CER...
# 2    IL  60629.0  ...  39. CONTAMINATION PREVENTED DURING FOOD PREPAR...
# 3    IL  60629.0  ...                                                NaN
# 4    IL  60652.0  ...  38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - ...
#
#     latitude  longitude                                 location  inc_year  \
# 0  41.859630 -87.630125  (41.85962967731282, -87.63012489927696)      2024
# 1  41.895745 -87.680303   (41.89574547491271, -87.6803034146672)      2024
# 2  41.786536 -87.692440  (41.78653601978693, -87.69244039932887)      2024
# 3  41.786536 -87.692440  (41.78653601978693, -87.69244039932887)      2024
# 4  41.736414 -87.702192   (41.7364142354004, -87.70219239358123)      2024
#
#    inc_month inc_week  inc_day  year_month  count
# 0          4        0       22   2024-4-01      1
# 1          4        0       22   2024-4-01      1
# 2          4        0       22   2024-4-01      1
# 3          4        0       22   2024-4-01      1
# 4          4        0       22   2024-4-01      1
#
# [5 rows x 23 columns]

# %%
hd.tail()
# Out:
#         inspection_id                      dba_name  \
# 271018         104236                    TEMPO CAFE
# 271019          67757  DUNKIN DONUTS/BASKIN-ROBBINS
# 271020          67732                     WOLCOTT'S
# 271021          67738        MICHAEL'S ON MAIN CAFE
# 271022          52234                      Cafe 608
#
#                             aka_name   license_ facility_type  \
# 271018                    TEMPO CAFE    80916.0    Restaurant
# 271019  DUNKIN DONUTS/BASKIN-ROBBINS  1380279.0    Restaurant
# 271020                       TROQUET  1992039.0    Restaurant
# 271021        MICHAEL'S ON MAIN CAFE  2008948.0    Restaurant
# 271022                      Cafe 608  2013328.0    Restaurant
#
#                    risk                address     city state      zip  ...  \
# 271018    Risk 1 (High)       6 E CHESTNUT ST   CHICAGO    IL  60611.0  ...
# 271019  Risk 2 (Medium)     100 W RANDOLPH ST   CHICAGO    IL  60601.0  ...
# 271020    Risk 1 (High)   1834 W MONTROSE AVE   CHICAGO    IL  60613.0  ...
# 271021    Risk 1 (High)  8750 W BRYN WAWR AVE   CHICAGO    IL  60631.0  ...
# 271022    Risk 1 (High)       608 W BARRY AVE   CHICAGO    IL  60657.0  ...
#
#                                                violations   latitude  \
# 271018  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.898431
# 271019                                                NaN  41.884586
# 271020                                                NaN  41.961606
# 271021  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...        NaN
# 271022                                                NaN  41.938007
#
#         longitude                                  location  inc_year  \
# 271018 -87.628009    (41.89843137207629, -87.6280091630558)      2010
# 271019 -87.631010   (41.88458626715456, -87.63101044588599)      2010
# 271020 -87.675967  (41.961605669949854, -87.67596676683779)      2010
# 271021        NaN                                       NaN      2010
# 271022 -87.644755   (41.938006880423615, -87.6447545707008)      2010
#
#         inc_month inc_week  inc_day  year_month  count
# 271018          1        0        4   2010-1-01      1
# 271019          1        0        4   2010-1-01      1
# 271020          1        0        4   2010-1-01      1
# 271021          1        0        4   2010-1-01      1
# 271022          1        0        4   2010-1-01      1
#
# [5 rows x 23 columns]

# %%
inspected_restaurants = hd.groupby('dba_name').filter(lambda x: len(x) > 1)

# %%
inspected_restaurants['Upgrade/Downgrade'] = np.where(inspected_restaurants['results'].shift(-1) != inspected_restaurants['results'], 'Yes', 'No')

# %%
inspected_restaurants['Pass/Fail'] = np.where(inspected_restaurants['results'] == 'Pass', 'Pass', 'Fail')

# %%
inspected_restaurants['Result Numerical'] = (inspected_restaurants['results'] == 'Pass').astype(int)

# %%
restaurant_inspection_counts = inspected_restaurants.groupby('dba_name').size().reset_index(name='Inspection Count')

# %%
inspection_scores = inspected_restaurants.groupby('dba_name')['Result Numerical'].agg(['mean', 'median']).reset_index()

# %%
restaurant_data = pd.merge(restaurant_inspection_counts, inspection_scores, on='dba_name', how='left')

# %%
restaurant_data['Inspection Summary'] = restaurant_data['dba_name'] + ' - Inspected ' + restaurant_data['Inspection Count'].astype(str) + ' times'

# %%
print(f"Total number of inspected restaurants: {len(inspected_restaurants)}")
# Out:
# Total number of inspected restaurants: 265026

# %%
upgrade_downgrade_counts = inspected_restaurants['Upgrade/Downgrade'].value_counts()

# %%
pivot_table = inspected_restaurants.pivot_table(index='dba_name', columns='results', aggfunc='size', fill_value=0)
print("Pivoted table:")
print(pivot_table)
# Out:
# Pivoted table:
# results                       Business Not Located  Fail  No Entry  Not Ready  \
# dba_name
# #1 CHINA EXPRESS, LTD.                           0     0         0          0
# #1 CHOP SUEY                                     0     9         2          0
# #1 CHOP SUEY RESTAURANT, INC                     0     1         1          0
# #1 DELI                                          0     0         0          0
# #1 DELI, INC                                     0     0         2          0
# ...                                            ...   ...       ...        ...
# rendezvous bistro                                0     3         0          0
# ropa restaurant & wine bar                       0     0         0          0
# stockton                                         0     3         0          0
# subway restaurant 1                              0     0         0          0
# tien giang restaurant                            0     3         0          0
#
# results                       Out of Business  Pass  Pass w/ Conditions
# dba_name
# #1 CHINA EXPRESS, LTD.                      1     1                   0
# #1 CHOP SUEY                                2    24                   4
# #1 CHOP SUEY RESTAURANT, INC                0     3                   0
# #1 DELI                                     0     0                   2
# #1 DELI, INC                                2     3                   1
# ...                                       ...   ...                 ...
# rendezvous bistro                           1     2                   0
# ropa restaurant & wine bar                  1     1                   0
# stockton                                    1     4                   0
# subway restaurant 1                         1     2                   1
# tien giang restaurant                       0     1                   0
#
# [26395 rows x 7 columns]

# %%
upgrade_downgrade_counts = inspected_restaurants.groupby(['dba_name', 'Upgrade/Downgrade']).size().unstack(fill_value=0).reset_index()
upgrade_downgrade_counts = upgrade_downgrade_counts.rename(columns={'No': 'Upgraded', 'Yes': 'Downgraded'})

# %%
pass_fail_counts = inspected_restaurants.groupby(['dba_name', 'Pass/Fail']).size().unstack(fill_value=0).reset_index()

# %%
merged_data = restaurant_inspection_counts.merge(upgrade_downgrade_counts, on='dba_name', how='left')
merged_data = merged_data.merge(pass_fail_counts, on='dba_name', how='left')

# %%
merged_data.to_csv('restaurant_inspection_summary.csv')

# %% [markdown]
# **List of restaurants who are failing their inspections**

# %% [markdown]
# areas with common fail inspections

# %%
#create a geodataframe from build
hd_geo = gpd.GeoDataFrame(
hd, geometry= gpd.points_from_xy(hd['longitude'], hd['latitude']), crs="EPSG:4326"
)

# %%
#join ward
hd_geo_w = hd_geo.sjoin(ward, how="left", predicate='within' )

# %%
#drop index
hd_geo_w= hd_geo_w.drop(columns=['index_right'], axis=1)

# %%
#join police
hd_geo_w_p = hd_geo_w.sjoin(police, how="left", predicate='within')

# %%
hd_geo_w_p.head()
# Out:
#    inspection_id                      dba_name                      aka_name  \
# 0        2593156                     MARIANO'S                     MARIANO'S
# 1        2593140              ALL TOGETHER NOW               ALLTOGETHER NOW
# 2        2593144          MERCADITO LA MONARCA          MERCADITO LA MONARCA
# 3        2593149  Supermercado  Castillos, Inc  Supermercado  Castillos, Inc
# 4        2593119             SKY CHOP SUEY INC             SKY CHOP SUEY INC
#
#     license_  facility_type             risk              address     city  \
# 0  2271471.0  Grocery Store    Risk 1 (High)     1615 S CLARK ST   CHICAGO
# 1  2589262.0     Restaurant    Risk 1 (High)  2119 W CHICAGO AVE   CHICAGO
# 2  2956597.0  Grocery Store    Risk 1 (High)      2732 W 59TH ST   CHICAGO
# 3  2004134.0  Grocery Store  Risk 2 (Medium)      2732 W 59TH ST   CHICAGO
# 4    25159.0     Restaurant    Risk 1 (High)   8616 S KEDZIE AVE   CHICAGO
#
#   state      zip  ... inc_day year_month count                    geometry  \
# 0    IL  60616.0  ...      22  2024-4-01     1  POINT (-87.63012 41.85963)
# 1    IL  60622.0  ...      22  2024-4-01     1  POINT (-87.68030 41.89575)
# 2    IL  60629.0  ...      22  2024-4-01     1  POINT (-87.69244 41.78654)
# 3    IL  60629.0  ...      22  2024-4-01     1  POINT (-87.69244 41.78654)
# 4    IL  60652.0  ...      22  2024-4-01     1  POINT (-87.70219 41.73641)
#
#       shape_area     shape_leng ward  index_right  dist_label  dist_num
# 0  123341548.953  81530.2751668    3         21.0         1ST         1
# 1  69757593.8542   102569.70148    1         14.0        12TH        12
# 2  103143638.546  97901.3238332   16         12.0         8TH         8
# 3  103143638.546  97901.3238332   16         12.0         8TH         8
# 4  183256966.765   65699.143324   18         12.0         8TH         8
#
# [5 rows x 30 columns]

# %%
hd_geo_w_p.tail(20)
# Out:
#         inspection_id                          dba_name  \
# 271003         164252        SUPER DOG'S SUBMARINES INC
# 271004         124257                        LIDO, INC.
# 271005          80208                     Dunkin Donuts
# 271006         134239              BORNIQUEN RESTAURANT
# 271007         124256  FERNANDO'S MEXICAN GRILL & PIZZA
# 271008          70273          THE GREAT AMERICAN BAGEL
# 271009          67848           SAFAH FOOD & LIQUOR INC
# 271010          67739            EL TACONAZO RESTAURANT
# 271011          70272                      THE DOGHOUSE
# 271012          68250      Tots Express Learning Center
# 271013         134238        FUNSTON ANNEX ELEM. SCHOOL
# 271014         118296               FAIRPLAY FINER FOOD
# 271015          98313                     WHIPPLE STORE
# 271016          67733                         WOLCOTT'S
# 271017          70269                       mr.daniel's
# 271018         104236                        TEMPO CAFE
# 271019          67757      DUNKIN DONUTS/BASKIN-ROBBINS
# 271020          67732                         WOLCOTT'S
# 271021          67738            MICHAEL'S ON MAIN CAFE
# 271022          52234                          Cafe 608
#
#                                  aka_name   license_          facility_type  \
# 271003         SUPER DOG'S SUBMARINES INC  2008759.0             Restaurant
# 271004                      LIDO BANQUETS    17145.0             Restaurant
# 271005                      Dunkin Donuts  2013340.0             Restaurant
# 271006               BORNIQUEN RESTAURANT    32942.0             Restaurant
# 271007   FERNANDO'S MEXICAN GRILL & PIZZA  1915768.0             Restaurant
# 271008  THE GREAT AMERICAN BAGEL (T3-H10)  1879164.0             Restaurant
# 271009            SAFAH FOOD & LIQUOR INC    14103.0          Grocery Store
# 271010             EL TACONAZO RESTAURANT  1964480.0             Restaurant
# 271011                       THE DOGHOUSE  1681450.0                    NaN
# 271012                                NaN  2002536.0  Daycare (2 - 6 Years)
# 271013       FUNSTON (ANNEX) ELEM. SCHOOL  1964634.0                 School
# 271014                FAIRPLAY FINER FOOD    10940.0          Grocery Store
# 271015                      WHIPPLE STORE  2009114.0          Grocery Store
# 271016                            TROQUET  1992040.0             Restaurant
# 271017                        mr.daniel's  1899292.0             Restaurant
# 271018                         TEMPO CAFE    80916.0             Restaurant
# 271019       DUNKIN DONUTS/BASKIN-ROBBINS  1380279.0             Restaurant
# 271020                            TROQUET  1992039.0             Restaurant
# 271021             MICHAEL'S ON MAIN CAFE  2008948.0             Restaurant
# 271022                           Cafe 608  2013328.0             Restaurant
#
#                    risk                    address     city state      zip  \
# 271003  Risk 2 (Medium)           1442 W 103RD ST   CHICAGO    IL  60643.0
# 271004    Risk 1 (High)      5504 N MILWAUKEE AVE   CHICAGO    IL  60630.0
# 271005    Risk 1 (High)  2800 W Lawrence AVE BLDG   CHICAGO    IL  60625.0
# 271006    Risk 1 (High)     1720 N CALIFORNIA AVE   CHICAGO    IL  60647.0
# 271007    Risk 1 (High)         7148 N HARLEM AVE   CHICAGO    IL  60631.0
# 271008    Risk 1 (High)         11601 W TOUHY AVE   CHICAGO    IL  60666.0
# 271009     Risk 3 (Low)         7105 S RACINE AVE   CHICAGO    IL  60636.0
# 271010    Risk 1 (High)         5849 S KEDZIE AVE   CHICAGO    IL  60629.0
# 271011    Risk 1 (High)         11601 W TOUHY AVE   CHICAGO    IL  60666.0
# 271012    Risk 1 (High)      1705-07 E 87th ST FL   CHICAGO    IL  60617.0
# 271013    Risk 1 (High)       3616 W ARMITAGE AVE   CHICAGO    IL  60647.0
# 271014    Risk 1 (High)        2200 S WESTERN AVE   CHICAGO    IL  60608.0
# 271015     Risk 3 (Low)         4301 N WHIPPLE ST   CHICAGO    IL  60618.0
# 271016    Risk 1 (High)       1834 W MONTROSE AVE   CHICAGO    IL  60613.0
# 271017    Risk 1 (High)        5645 W BELMONT AVE   CHICAGO    IL  60634.0
# 271018    Risk 1 (High)           6 E CHESTNUT ST   CHICAGO    IL  60611.0
# 271019  Risk 2 (Medium)         100 W RANDOLPH ST   CHICAGO    IL  60601.0
# 271020    Risk 1 (High)       1834 W MONTROSE AVE   CHICAGO    IL  60613.0
# 271021    Risk 1 (High)      8750 W BRYN WAWR AVE   CHICAGO    IL  60631.0
# 271022    Risk 1 (High)           608 W BARRY AVE   CHICAGO    IL  60657.0
#
#         ... inc_day year_month count                    geometry  \
# 271003  ...       5  2010-1-01     1  POINT (-87.65895 41.70685)
# 271004  ...       5  2010-1-01     1  POINT (-87.77347 41.98175)
# 271005  ...       5  2010-1-01     1  POINT (-87.69872 41.96864)
# 271006  ...       5  2010-1-01     1  POINT (-87.69720 41.91269)
# 271007  ...       5  2010-1-01     1  POINT (-87.80679 42.01136)
# 271008  ...       5  2010-1-01     1  POINT (-87.90687 42.00875)
# 271009  ...       5  2010-1-01     1  POINT (-87.65396 41.76490)
# 271010  ...       5  2010-1-01     1  POINT (-87.70321 41.78662)
# 271011  ...       5  2010-1-01     1  POINT (-87.90687 42.00875)
# 271012  ...       5  2010-1-01     1  POINT (-87.58249 41.73685)
# 271013  ...       5  2010-1-01     1  POINT (-87.71746 41.91738)
# 271014  ...       5  2010-1-01     1  POINT (-87.68579 41.85198)
# 271015  ...       5  2010-1-01     1  POINT (-87.70438 41.95949)
# 271016  ...       4  2010-1-01     1  POINT (-87.67597 41.96161)
# 271017  ...       4  2010-1-01     1  POINT (-87.76832 41.93844)
# 271018  ...       4  2010-1-01     1  POINT (-87.62801 41.89843)
# 271019  ...       4  2010-1-01     1  POINT (-87.63101 41.88459)
# 271020  ...       4  2010-1-01     1  POINT (-87.67597 41.96161)
# 271021  ...       4  2010-1-01     1                 POINT EMPTY
# 271022  ...       4  2010-1-01     1  POINT (-87.64475 41.93801)
#
#            shape_area     shape_leng ward  index_right  dist_label  dist_num
# 271003  214115105.843  102339.878771   19          8.0        22ND        22
# 271004  125334245.511  76714.8413866   45         11.0        16TH        16
# 271005  95929056.6812  48374.9136177   40          1.0        20TH        20
# 271006  69757593.8542   102569.70148    1          6.0        14TH        14
# 271007   484238238.97  252516.011482   41         11.0        16TH        16
# 271008   484238238.97  252516.011482   41         11.0        16TH        16
# 271009  120539114.428  69925.2023858    6         16.0         7TH         7
# 271010  143011018.899  90165.7974072   14         12.0         8TH         8
# 271011   484238238.97  252516.011482   41         11.0        16TH        16
# 271012  162845783.237  89830.3932001    8         18.0         4TH         4
# 271013  70391187.5645  69089.8822547   26          5.0        25TH        25
# 271014  142879662.243  119977.208819   28         20.0        10TH        10
# 271015  70214893.3538  47062.4200753   33          0.0        17TH        17
# 271016  87363636.3844  53371.3055095   47          4.0        19TH        19
# 271017  69739758.4303  50635.7831536   31          5.0        25TH        25
# 271018  53934808.8716  110739.852187    2         13.0        18TH        18
# 271019  71494714.6921  62491.4598917   42         21.0         1ST         1
# 271020  87363636.3844  53371.3055095   47          4.0        19TH        19
# 271021            NaN            NaN  NaN          NaN         NaN       NaN
# 271022  49422863.0048  46466.2721725   44          4.0        19TH        19
#
# [20 rows x 30 columns]

# %% [markdown]
# **Most fails from restaurants in city and zip**

# %%
#create a geodataframe from build
hd_geo = gpd.GeoDataFrame(
hd, geometry= gpd.points_from_xy(hd['longitude'], hd['latitude']), crs="EPSG:4326"
)

# %%
#join ward
hd_geo_w = hd_geo.sjoin(ward, how="left", predicate='within' )

# %%
#drop index
hd_geo_w= hd_geo_w.drop(columns=['index_right'], axis=1)

# %%
#join police
hd_geo_w_p = hd_geo_w.sjoin(police, how="left", predicate='within')

# %% [markdown]
# **Tidy Data Principles**

# %%
hd_geo_w_p.head()
# Out:
#    inspection_id                      dba_name                      aka_name  \
# 0        2593156                     MARIANO'S                     MARIANO'S
# 1        2593140              ALL TOGETHER NOW               ALLTOGETHER NOW
# 2        2593144          MERCADITO LA MONARCA          MERCADITO LA MONARCA
# 3        2593149  Supermercado  Castillos, Inc  Supermercado  Castillos, Inc
# 4        2593119             SKY CHOP SUEY INC             SKY CHOP SUEY INC
#
#     license_  facility_type             risk              address     city  \
# 0  2271471.0  Grocery Store    Risk 1 (High)     1615 S CLARK ST   CHICAGO
# 1  2589262.0     Restaurant    Risk 1 (High)  2119 W CHICAGO AVE   CHICAGO
# 2  2956597.0  Grocery Store    Risk 1 (High)      2732 W 59TH ST   CHICAGO
# 3  2004134.0  Grocery Store  Risk 2 (Medium)      2732 W 59TH ST   CHICAGO
# 4    25159.0     Restaurant    Risk 1 (High)   8616 S KEDZIE AVE   CHICAGO
#
#   state      zip  ... inc_day year_month count                    geometry  \
# 0    IL  60616.0  ...      22  2024-4-01     1  POINT (-87.63012 41.85963)
# 1    IL  60622.0  ...      22  2024-4-01     1  POINT (-87.68030 41.89575)
# 2    IL  60629.0  ...      22  2024-4-01     1  POINT (-87.69244 41.78654)
# 3    IL  60629.0  ...      22  2024-4-01     1  POINT (-87.69244 41.78654)
# 4    IL  60652.0  ...      22  2024-4-01     1  POINT (-87.70219 41.73641)
#
#       shape_area     shape_leng ward  index_right  dist_label  dist_num
# 0  123341548.953  81530.2751668    3         21.0         1ST         1
# 1  69757593.8542   102569.70148    1         14.0        12TH        12
# 2  103143638.546  97901.3238332   16         12.0         8TH         8
# 3  103143638.546  97901.3238332   16         12.0         8TH         8
# 4  183256966.765   65699.143324   18         12.0         8TH         8
#
# [5 rows x 30 columns]

# %%
hd_geo_w_p.tail(20)
# Out:
#         inspection_id                          dba_name  \
# 271003         164252        SUPER DOG'S SUBMARINES INC
# 271004         124257                        LIDO, INC.
# 271005          80208                     Dunkin Donuts
# 271006         134239              BORNIQUEN RESTAURANT
# 271007         124256  FERNANDO'S MEXICAN GRILL & PIZZA
# 271008          70273          THE GREAT AMERICAN BAGEL
# 271009          67848           SAFAH FOOD & LIQUOR INC
# 271010          67739            EL TACONAZO RESTAURANT
# 271011          70272                      THE DOGHOUSE
# 271012          68250      Tots Express Learning Center
# 271013         134238        FUNSTON ANNEX ELEM. SCHOOL
# 271014         118296               FAIRPLAY FINER FOOD
# 271015          98313                     WHIPPLE STORE
# 271016          67733                         WOLCOTT'S
# 271017          70269                       mr.daniel's
# 271018         104236                        TEMPO CAFE
# 271019          67757      DUNKIN DONUTS/BASKIN-ROBBINS
# 271020          67732                         WOLCOTT'S
# 271021          67738            MICHAEL'S ON MAIN CAFE
# 271022          52234                          Cafe 608
#
#                                  aka_name   license_          facility_type  \
# 271003         SUPER DOG'S SUBMARINES INC  2008759.0             Restaurant
# 271004                      LIDO BANQUETS    17145.0             Restaurant
# 271005                      Dunkin Donuts  2013340.0             Restaurant
# 271006               BORNIQUEN RESTAURANT    32942.0             Restaurant
# 271007   FERNANDO'S MEXICAN GRILL & PIZZA  1915768.0             Restaurant
# 271008  THE GREAT AMERICAN BAGEL (T3-H10)  1879164.0             Restaurant
# 271009            SAFAH FOOD & LIQUOR INC    14103.0          Grocery Store
# 271010             EL TACONAZO RESTAURANT  1964480.0             Restaurant
# 271011                       THE DOGHOUSE  1681450.0                    NaN
# 271012                                NaN  2002536.0  Daycare (2 - 6 Years)
# 271013       FUNSTON (ANNEX) ELEM. SCHOOL  1964634.0                 School
# 271014                FAIRPLAY FINER FOOD    10940.0          Grocery Store
# 271015                      WHIPPLE STORE  2009114.0          Grocery Store
# 271016                            TROQUET  1992040.0             Restaurant
# 271017                        mr.daniel's  1899292.0             Restaurant
# 271018                         TEMPO CAFE    80916.0             Restaurant
# 271019       DUNKIN DONUTS/BASKIN-ROBBINS  1380279.0             Restaurant
# 271020                            TROQUET  1992039.0             Restaurant
# 271021             MICHAEL'S ON MAIN CAFE  2008948.0             Restaurant
# 271022                           Cafe 608  2013328.0             Restaurant
#
#                    risk                    address     city state      zip  \
# 271003  Risk 2 (Medium)           1442 W 103RD ST   CHICAGO    IL  60643.0
# 271004    Risk 1 (High)      5504 N MILWAUKEE AVE   CHICAGO    IL  60630.0
# 271005    Risk 1 (High)  2800 W Lawrence AVE BLDG   CHICAGO    IL  60625.0
# 271006    Risk 1 (High)     1720 N CALIFORNIA AVE   CHICAGO    IL  60647.0
# 271007    Risk 1 (High)         7148 N HARLEM AVE   CHICAGO    IL  60631.0
# 271008    Risk 1 (High)         11601 W TOUHY AVE   CHICAGO    IL  60666.0
# 271009     Risk 3 (Low)         7105 S RACINE AVE   CHICAGO    IL  60636.0
# 271010    Risk 1 (High)         5849 S KEDZIE AVE   CHICAGO    IL  60629.0
# 271011    Risk 1 (High)         11601 W TOUHY AVE   CHICAGO    IL  60666.0
# 271012    Risk 1 (High)      1705-07 E 87th ST FL   CHICAGO    IL  60617.0
# 271013    Risk 1 (High)       3616 W ARMITAGE AVE   CHICAGO    IL  60647.0
# 271014    Risk 1 (High)        2200 S WESTERN AVE   CHICAGO    IL  60608.0
# 271015     Risk 3 (Low)         4301 N WHIPPLE ST   CHICAGO    IL  60618.0
# 271016    Risk 1 (High)       1834 W MONTROSE AVE   CHICAGO    IL  60613.0
# 271017    Risk 1 (High)        5645 W BELMONT AVE   CHICAGO    IL  60634.0
# 271018    Risk 1 (High)           6 E CHESTNUT ST   CHICAGO    IL  60611.0
# 271019  Risk 2 (Medium)         100 W RANDOLPH ST   CHICAGO    IL  60601.0
# 271020    Risk 1 (High)       1834 W MONTROSE AVE   CHICAGO    IL  60613.0
# 271021    Risk 1 (High)      8750 W BRYN WAWR AVE   CHICAGO    IL  60631.0
# 271022    Risk 1 (High)           608 W BARRY AVE   CHICAGO    IL  60657.0
#
#         ... inc_day year_month count                    geometry  \
# 271003  ...       5  2010-1-01     1  POINT (-87.65895 41.70685)
# 271004  ...       5  2010-1-01     1  POINT (-87.77347 41.98175)
# 271005  ...       5  2010-1-01     1  POINT (-87.69872 41.96864)
# 271006  ...       5  2010-1-01     1  POINT (-87.69720 41.91269)
# 271007  ...       5  2010-1-01     1  POINT (-87.80679 42.01136)
# 271008  ...       5  2010-1-01     1  POINT (-87.90687 42.00875)
# 271009  ...       5  2010-1-01     1  POINT (-87.65396 41.76490)
# 271010  ...       5  2010-1-01     1  POINT (-87.70321 41.78662)
# 271011  ...       5  2010-1-01     1  POINT (-87.90687 42.00875)
# 271012  ...       5  2010-1-01     1  POINT (-87.58249 41.73685)
# 271013  ...       5  2010-1-01     1  POINT (-87.71746 41.91738)
# 271014  ...       5  2010-1-01     1  POINT (-87.68579 41.85198)
# 271015  ...       5  2010-1-01     1  POINT (-87.70438 41.95949)
# 271016  ...       4  2010-1-01     1  POINT (-87.67597 41.96161)
# 271017  ...       4  2010-1-01     1  POINT (-87.76832 41.93844)
# 271018  ...       4  2010-1-01     1  POINT (-87.62801 41.89843)
# 271019  ...       4  2010-1-01     1  POINT (-87.63101 41.88459)
# 271020  ...       4  2010-1-01     1  POINT (-87.67597 41.96161)
# 271021  ...       4  2010-1-01     1                 POINT EMPTY
# 271022  ...       4  2010-1-01     1  POINT (-87.64475 41.93801)
#
#            shape_area     shape_leng ward  index_right  dist_label  dist_num
# 271003  214115105.843  102339.878771   19          8.0        22ND        22
# 271004  125334245.511  76714.8413866   45         11.0        16TH        16
# 271005  95929056.6812  48374.9136177   40          1.0        20TH        20
# 271006  69757593.8542   102569.70148    1          6.0        14TH        14
# 271007   484238238.97  252516.011482   41         11.0        16TH        16
# 271008   484238238.97  252516.011482   41         11.0        16TH        16
# 271009  120539114.428  69925.2023858    6         16.0         7TH         7
# 271010  143011018.899  90165.7974072   14         12.0         8TH         8
# 271011   484238238.97  252516.011482   41         11.0        16TH        16
# 271012  162845783.237  89830.3932001    8         18.0         4TH         4
# 271013  70391187.5645  69089.8822547   26          5.0        25TH        25
# 271014  142879662.243  119977.208819   28         20.0        10TH        10
# 271015  70214893.3538  47062.4200753   33          0.0        17TH        17
# 271016  87363636.3844  53371.3055095   47          4.0        19TH        19
# 271017  69739758.4303  50635.7831536   31          5.0        25TH        25
# 271018  53934808.8716  110739.852187    2         13.0        18TH        18
# 271019  71494714.6921  62491.4598917   42         21.0         1ST         1
# 271020  87363636.3844  53371.3055095   47          4.0        19TH        19
# 271021            NaN            NaN  NaN          NaN         NaN       NaN
# 271022  49422863.0048  46466.2721725   44          4.0        19TH        19
#
# [20 rows x 30 columns]

# %%
hd_geo_w_p.columns
# Out:
# Index(['inspection_id', 'dba_name', 'aka_name', 'license_', 'facility_type',
#        'risk', 'address', 'city', 'state', 'zip', 'inspection_date',
#        'inspection_type', 'results', 'violations', 'latitude', 'longitude',
#        'location', 'inc_year', 'inc_month', 'inc_week', 'inc_day',
#        'year_month', 'count', 'geometry', 'shape_area', 'shape_leng', 'ward',
#        'index_right', 'dist_label', 'dist_num'],
#       dtype='object')

# %%
hd_geo_w_p.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 271023 entries, 0 to 271022
# Data columns (total 30 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   inspection_id    271023 non-null  int64
#  1   dba_name         271023 non-null  object
#  2   aka_name         268551 non-null  object
#  3   license_         271005 non-null  float64
#  4   facility_type    265882 non-null  object
#  5   risk             270940 non-null  object
#  6   address          271023 non-null  object
#  7   city             270862 non-null  object
#  8   state            270964 non-null  object
#  9   zip              270972 non-null  float64
#  10  inspection_date  271023 non-null  datetime64[ns]
#  11  inspection_type  271022 non-null  object
#  12  results          271023 non-null  object
#  13  violations       196697 non-null  object
#  14  latitude         270085 non-null  float64
#  15  longitude        270085 non-null  float64
#  16  location         270085 non-null  object
#  17  inc_year         271023 non-null  int32
#  18  inc_month        271023 non-null  int32
#  19  inc_week         271023 non-null  int32
#  20  inc_day          271023 non-null  int32
#  21  year_month       271023 non-null  object
#  22  count            271023 non-null  int64
#  23  geometry         271023 non-null  geometry
#  24  shape_area       269796 non-null  object
#  25  shape_leng       269796 non-null  object
#  26  ward             269796 non-null  object
#  27  index_right      269796 non-null  float64
#  28  dist_label       269796 non-null  object
#  29  dist_num         269796 non-null  object
# dtypes: datetime64[ns](1), float64(5), geometry(1), int32(4), int64(2), object(17)
# memory usage: 60.0+ MB

# %%
hd_geo_w_p.shape
# Out:
# (271023, 30)

# %% [markdown]
# Filter, conditional logic and a loop
# (sorted data by zip and city)

# %%
hd_geo_w_p[(hd_geo_w_p['facility_type'] == "Restaurant")]
# Out:
#         inspection_id                      dba_name  \
# 1             2593140              ALL TOGETHER NOW
# 4             2593119             SKY CHOP SUEY INC
# 6             2593083  NYC HALAL EATS ILLINOIS  LLC
# 8             2593107          REGGIE'S BAR & GRILL
# 11            2593096           AMERICANA SUBMARINE
# ...               ...                           ...
# 271018         104236                    TEMPO CAFE
# 271019          67757  DUNKIN DONUTS/BASKIN-ROBBINS
# 271020          67732                     WOLCOTT'S
# 271021          67738        MICHAEL'S ON MAIN CAFE
# 271022          52234                      Cafe 608
#
#                             aka_name   license_ facility_type  \
# 1                    ALLTOGETHER NOW  2589262.0    Restaurant
# 4                  SKY CHOP SUEY INC    25159.0    Restaurant
# 6       NYC HALAL EATS ILLINOIS  LLC  2961706.0    Restaurant
# 8               REGGIE'S BAR & GRILL  2630737.0    Restaurant
# 11               AMERICANA SUBMARINE  2961733.0    Restaurant
# ...                              ...        ...           ...
# 271018                    TEMPO CAFE    80916.0    Restaurant
# 271019  DUNKIN DONUTS/BASKIN-ROBBINS  1380279.0    Restaurant
# 271020                       TROQUET  1992039.0    Restaurant
# 271021        MICHAEL'S ON MAIN CAFE  2008948.0    Restaurant
# 271022                      Cafe 608  2013328.0    Restaurant
#
#                    risk                address     city state      zip  ...  \
# 1         Risk 1 (High)    2119 W CHICAGO AVE   CHICAGO    IL  60622.0  ...
# 4         Risk 1 (High)     8616 S KEDZIE AVE   CHICAGO    IL  60652.0  ...
# 6       Risk 2 (Medium)      2657 W DEVON AVE   CHICAGO    IL  60659.0  ...
# 8         Risk 1 (High)       2105 S STATE ST   CHICAGO    IL  60616.0  ...
# 11      Risk 2 (Medium)        400 S CLARK ST   CHICAGO    IL  60605.0  ...
# ...                 ...                    ...      ...   ...      ...  ...
# 271018    Risk 1 (High)       6 E CHESTNUT ST   CHICAGO    IL  60611.0  ...
# 271019  Risk 2 (Medium)     100 W RANDOLPH ST   CHICAGO    IL  60601.0  ...
# 271020    Risk 1 (High)   1834 W MONTROSE AVE   CHICAGO    IL  60613.0  ...
# 271021    Risk 1 (High)  8750 W BRYN WAWR AVE   CHICAGO    IL  60631.0  ...
# 271022    Risk 1 (High)       608 W BARRY AVE   CHICAGO    IL  60657.0  ...
#
#        inc_day year_month count                    geometry     shape_area  \
# 1           22  2024-4-01     1  POINT (-87.68030 41.89575)  69757593.8542
# 4           22  2024-4-01     1  POINT (-87.70219 41.73641)  183256966.765
# 6           19  2024-4-01     1  POINT (-87.69706 41.99750)  80692979.8113
# 8           19  2024-4-01     1  POINT (-87.62696 41.85406)  123341548.953
# 11          19  2024-4-01     1  POINT (-87.63089 41.87682)  126006901.096
# ...        ...        ...   ...                         ...            ...
# 271018       4  2010-1-01     1  POINT (-87.62801 41.89843)  53934808.8716
# 271019       4  2010-1-01     1  POINT (-87.63101 41.88459)  71494714.6921
# 271020       4  2010-1-01     1  POINT (-87.67597 41.96161)  87363636.3844
# 271021       4  2010-1-01     1                 POINT EMPTY            NaN
# 271022       4  2010-1-01     1  POINT (-87.64475 41.93801)  49422863.0048
#
#            shape_leng ward  index_right  dist_label  dist_num
# 1        102569.70148    1         14.0        12TH        12
# 4        65699.143324   18         12.0         8TH         8
# 6       46116.3788804   50         10.0        24TH        24
# 8       81530.2751668    3         21.0         1ST         1
# 11      119468.403755    4         21.0         1ST         1
# ...               ...  ...          ...         ...       ...
# 271018  110739.852187    2         13.0        18TH        18
# 271019  62491.4598917   42         21.0         1ST         1
# 271020  53371.3055095   47          4.0        19TH        19
# 271021            NaN  NaN          NaN         NaN       NaN
# 271022  46466.2721725   44          4.0        19TH        19
#
# [182293 rows x 30 columns]

# %%
hd_geo_w_p_sort = hd_geo_w_p.sort_values(by=['city'], ascending=True)

# %%
hd_geo_w_p_sort.head(5)
# Out:
#         inspection_id           dba_name           aka_name   license_  \
# 5473          2587155  MOJO SOUTH WACKER  MOJO SOUTH WACKER  2534918.0
# 120386        2050982  MOJO SOUTH WACKER  MOJO SOUTH WACKER  2534918.0
# 60430         2386974  MOJO SOUTH WACKER  MOJO SOUTH WACKER  2534918.0
# 119645        2059706  MOJO SOUTH WACKER  MOJO SOUTH WACKER  2534918.0
# 81522         2293744            NOURISH            NOURISH  2653129.0
#
#                            facility_type             risk            address  \
# 5473                          Restaurant    Risk 1 (High)   200 S WACKER DR
# 120386                        Restaurant    Risk 1 (High)   200 S WACKER DR
# 60430                         Restaurant    Risk 1 (High)   200 S WACKER DR
# 119645                        Restaurant    Risk 1 (High)   200 S WACKER DR
# 81522   Shared Kitchen User (Short Term)  Risk 2 (Medium)  1307 CARDINAL DR
#
#               city state      zip  ... inc_day  year_month count  \
# 5473    312CHICAGO    IL  60606.0  ...      19  2023-12-01     1
# 120386  312CHICAGO    IL  60606.0  ...      24   2017-5-01     1
# 60430   312CHICAGO    IL  60606.0  ...       9   2020-9-01     1
# 119645  312CHICAGO    IL  60606.0  ...       6   2017-6-01     1
# 81522    ALGONQUIN    IL  60102.0  ...      18   2019-6-01     1
#
#                           geometry     shape_area     shape_leng ward  \
# 5473    POINT (-87.63710 41.87928)  71494714.6921  62491.4598917   42
# 120386  POINT (-87.63710 41.87928)  71494714.6921  62491.4598917   42
# 60430   POINT (-87.63710 41.87928)  71494714.6921  62491.4598917   42
# 119645  POINT (-87.63710 41.87928)  71494714.6921  62491.4598917   42
# 81522                  POINT EMPTY            NaN            NaN  NaN
#
#         index_right  dist_label  dist_num
# 5473           21.0         1ST         1
# 120386         21.0         1ST         1
# 60430          21.0         1ST         1
# 119645         21.0         1ST         1
# 81522           NaN         NaN       NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# Tidy Principles - What do they do and What do they mean?
#
#
# *   Melt data: transforms wide data into long data(for multiple columns)
#
# *   Pivot data: pivot long data (often one column) into wide data(multiple columns)
#
# *   Joins data: this is used when we want two pieces of data joined together. This method also includes and follows through with using inner and left. Inner means together and left/right means on either side of that specific column.

# %%
hd_geo_w_p.head()
# Out:
#    inspection_id                      dba_name                      aka_name  \
# 0        2593156                     MARIANO'S                     MARIANO'S
# 1        2593140              ALL TOGETHER NOW               ALLTOGETHER NOW
# 2        2593144          MERCADITO LA MONARCA          MERCADITO LA MONARCA
# 3        2593149  Supermercado  Castillos, Inc  Supermercado  Castillos, Inc
# 4        2593119             SKY CHOP SUEY INC             SKY CHOP SUEY INC
#
#     license_  facility_type             risk              address     city  \
# 0  2271471.0  Grocery Store    Risk 1 (High)     1615 S CLARK ST   CHICAGO
# 1  2589262.0     Restaurant    Risk 1 (High)  2119 W CHICAGO AVE   CHICAGO
# 2  2956597.0  Grocery Store    Risk 1 (High)      2732 W 59TH ST   CHICAGO
# 3  2004134.0  Grocery Store  Risk 2 (Medium)      2732 W 59TH ST   CHICAGO
# 4    25159.0     Restaurant    Risk 1 (High)   8616 S KEDZIE AVE   CHICAGO
#
#   state      zip  ... inc_day year_month count                    geometry  \
# 0    IL  60616.0  ...      22  2024-4-01     1  POINT (-87.63012 41.85963)
# 1    IL  60622.0  ...      22  2024-4-01     1  POINT (-87.68030 41.89575)
# 2    IL  60629.0  ...      22  2024-4-01     1  POINT (-87.69244 41.78654)
# 3    IL  60629.0  ...      22  2024-4-01     1  POINT (-87.69244 41.78654)
# 4    IL  60652.0  ...      22  2024-4-01     1  POINT (-87.70219 41.73641)
#
#       shape_area     shape_leng ward  index_right  dist_label  dist_num
# 0  123341548.953  81530.2751668    3         21.0         1ST         1
# 1  69757593.8542   102569.70148    1         14.0        12TH        12
# 2  103143638.546  97901.3238332   16         12.0         8TH         8
# 3  103143638.546  97901.3238332   16         12.0         8TH         8
# 4  183256966.765   65699.143324   18         12.0         8TH         8
#
# [5 rows x 30 columns]

# %%
hd_df_melt = pd.melt( hd_geo_w_p_sort, id_vars=['city','zip','facility_type'], value_vars=['results'] )

# %%
hd_df_melt.head(20)
# Out:
#                     city      zip                     facility_type variable  \
# 0             312CHICAGO  60606.0                        Restaurant  results
# 1             312CHICAGO  60606.0                        Restaurant  results
# 2             312CHICAGO  60606.0                        Restaurant  results
# 3             312CHICAGO  60606.0                        Restaurant  results
# 4              ALGONQUIN  60102.0  Shared Kitchen User (Short Term)  results
# 5                  ALSIP  60803.0             Mobile Food Dispenser  results
# 6                  ALSIP  60803.0             Mobile Food Dispenser  results
# 7                  ALSIP  60803.0             Mobile Food Dispenser  results
# 8   BANNOCKBURNDEERFIELD  60015.0                          PUSHCART  results
# 9   BANNOCKBURNDEERFIELD  60015.0                          PUSHCART  results
# 10                BERWYN  60402.0   Shared Kitchen User (Long Term)  results
# 11                BERWYN  60402.0             Mobile Food Dispenser  results
# 12                BERWYN  60402.0                               NaN  results
# 13                BERWYN  60402.0   Shared Kitchen User (Long Term)  results
# 14                BERWYN  60402.0             Mobile Food Dispenser  results
# 15                BERWYN  60402.0              Mobile Food Preparer  results
# 16          BLOOMINGDALE  60108.0             Mobile Food Dispenser  results
# 17           BLUE ISLAND  60406.0   Shared Kitchen User (Long Term)  results
# 18           BLUE ISLAND  60406.0   Shared Kitchen User (Long Term)  results
# 19           BOLINGBROOK  60440.0   Shared Kitchen User (Long Term)  results
#
#                  value
# 0                 Pass
# 1            Not Ready
# 2   Pass w/ Conditions
# 3                 Pass
# 4   Pass w/ Conditions
# 5                 Pass
# 6                 Fail
# 7                 Pass
# 8   Pass w/ Conditions
# 9   Pass w/ Conditions
# 10     Out of Business
# 11                Pass
# 12                Pass
# 13                Pass
# 14                Fail
# 15  Pass w/ Conditions
# 16                Pass
# 17                Pass
# 18                Pass
# 19                Pass

# %%
hd_df_melt.sort_values(['facility_type','variable' ]).head(14)
# Out:
#            city      zip        facility_type variable            value
# 96433   CHICAGO  60604.0  (convenience store)  results             Pass
# 100623  CHICAGO  60649.0        (gas station)  results             Pass
# 100714  CHICAGO  60649.0        (gas station)  results             Fail
# 30334   CHICAGO  60659.0    1005 NURSING HOME  results  Out of Business
# 67739   CHICAGO  60659.0    1005 NURSING HOME  results             Pass
# 69270   CHICAGO  60659.0    1005 NURSING HOME  results             Fail
# 8553    CHICAGO  60639.0                 1023  results             Fail
# 8716    CHICAGO  60639.0                 1023  results             Pass
# 8725    CHICAGO  60639.0                 1023  results             Pass
# 48512   CHICAGO  60639.0                 1023  results  Out of Business
# 48554   CHICAGO  60639.0                 1023  results  Out of Business
# 95979   CHICAGO  60639.0                 1023  results             Pass
# 95982   CHICAGO  60639.0                 1023  results             Pass
# 96002   CHICAGO  60639.0                 1023  results             Pass

# %%
hd_melt_sort = hd_df_melt.sort_values(by=['city'], ascending=True).reset_index()

# %%
hd_melt_sort.head(20)
# Out:
#     index                  city      zip                     facility_type  \
# 0       0            312CHICAGO  60606.0                        Restaurant
# 1       1            312CHICAGO  60606.0                        Restaurant
# 2       2            312CHICAGO  60606.0                        Restaurant
# 3       3            312CHICAGO  60606.0                        Restaurant
# 4       4             ALGONQUIN  60102.0  Shared Kitchen User (Short Term)
# 5       5                 ALSIP  60803.0             Mobile Food Dispenser
# 6       6                 ALSIP  60803.0             Mobile Food Dispenser
# 7       7                 ALSIP  60803.0             Mobile Food Dispenser
# 8       8  BANNOCKBURNDEERFIELD  60015.0                          PUSHCART
# 9       9  BANNOCKBURNDEERFIELD  60015.0                          PUSHCART
# 10     14                BERWYN  60402.0             Mobile Food Dispenser
# 11     13                BERWYN  60402.0   Shared Kitchen User (Long Term)
# 12     15                BERWYN  60402.0              Mobile Food Preparer
# 13     11                BERWYN  60402.0             Mobile Food Dispenser
# 14     10                BERWYN  60402.0   Shared Kitchen User (Long Term)
# 15     12                BERWYN  60402.0                               NaN
# 16     16          BLOOMINGDALE  60108.0             Mobile Food Dispenser
# 17     17           BLUE ISLAND  60406.0   Shared Kitchen User (Long Term)
# 18     18           BLUE ISLAND  60406.0   Shared Kitchen User (Long Term)
# 19     19           BOLINGBROOK  60440.0   Shared Kitchen User (Long Term)
#
#    variable               value
# 0   results                Pass
# 1   results           Not Ready
# 2   results  Pass w/ Conditions
# 3   results                Pass
# 4   results  Pass w/ Conditions
# 5   results                Pass
# 6   results                Fail
# 7   results                Pass
# 8   results  Pass w/ Conditions
# 9   results  Pass w/ Conditions
# 10  results                Fail
# 11  results                Pass
# 12  results  Pass w/ Conditions
# 13  results                Pass
# 14  results     Out of Business
# 15  results                Pass
# 16  results                Pass
# 17  results                Pass
# 18  results                Pass
# 19  results                Pass

# %%
hd_geo_w_p['results'].value_counts()
# Out:
# results
# Pass                    139494
# Fail                     53006
# Pass w/ Conditions       41266
# Out of Business          22829
# No Entry                 10879
# Not Ready                 3463
# Business Not Located        86
# Name: count, dtype: int64

# %%
hd_geo_w_p['failed_results']=np.where(hd_geo_w_p['results'].isin(['Fail','Out of Business']),1,0)

# %%
hd_geo_w_p['failed_results'].value_counts()
# Out:
# failed_results
# 0    195188
# 1     75835
# Name: count, dtype: int64

# %%
hd_geo_w_p.groupby(['city','zip'])['failed_results'].sum().reset_index()

# %%
hd_geo_w_p.groupby(['city','zip'])['failed_results'].size().reset_index()
